# %% [markdown]
# ### Imports & env

# %%
from dotenv import load_dotenv
import os, json, sys

# Get the project root (one level above "notebooks")
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(project_root)

load_dotenv("../.env")
API_KEY = os.environ.get("YOUTUBE_API_KEY")
print("Has key:", bool(API_KEY))
# Out:
# Has key: True

# %% [markdown]
# ### Fetch(small test)

# %%
from src.youtube_fetcher import YouTubeFetcher

f = YouTubeFetcher(api_key=API_KEY)
meta = f.search_and_fetch("guitar chord lesson beginner intermediate advanced", max_results=200)
len(meta)
# Out:
# INFO:googleapiclient.discovery_cache:file_cache is only supported with oauth2client<4.0.0
# INFO:src.youtube_fetcher:Collected 1/200 ids
# INFO:src.youtube_fetcher:Collected 2/200 ids
# INFO:src.youtube_fetcher:Collected 3/200 ids
# INFO:src.youtube_fetcher:Collected 4/200 ids
# INFO:src.youtube_fetcher:Collected 5/200 ids
# INFO:src.youtube_fetcher:Collected 6/200 ids
# INFO:src.youtube_fetcher:Collected 7/200 ids
# INFO:src.youtube_fetcher:Collected 8/200 ids
# INFO:src.youtube_fetcher:Collected 9/200 ids
# INFO:src.youtube_fetcher:Collected 10/200 ids
# INFO:src.youtube_fetcher:Collected 11/200 ids
# INFO:src.youtube_fetcher:Collected 12/200 ids
# INFO:src.youtube_fetcher:Collected 13/200 ids
# INFO:src.youtube_fetcher:Collected 14/200 ids
# INFO:src.youtube_fetcher:Collected 15/200 ids
# INFO:src.youtube_fetcher:Collected 16/200 ids
# INFO:src.youtube_fetcher:Collected 17/200 ids
# INFO:src.youtube_fetcher:Collected 18/200 ids
# INFO:src.youtube_fetcher:Collected 19/200 ids
# ...

# %% [markdown]
# ### Save & Preview

# %%
import pandas as pd

df = pd.DataFrame(meta)
df.head()
df.to_parquet("../data/raw/guitar_sample_parquet", index=False)

# %%
df
# Out:
#         video_id                                              title  \
# 0    WN4IoK7ecAU  How to Teach Yourself Guitar in 2025 (Save YEA...
# 1    4WVkDrb6d5A           A Good, Quick Intermediate Guitar Lesson
# 2    sDjeY1jI2Z8         5 GREAT chord tricks everyone should know!
# 3    sxYG1EJMnLY                Beautiful chords in F #guitarchords
# 4    -iV-7XhUMT0  Are You An Intermediate Or Advanced Guitar Pla...
# ..           ...                                                ...
# 195  Kq-OcVxtJEM  Intermediate Bluegrass Lick in Key of G (Blueg...
# 196  AY-vkn_iBI8                            GUITAR SCALES Made Easy
# 197  jTCyiq5mjn8  Learn The Fretboard - How To Memorize The Note...
# 198  c59Xzi4tnjc  Eric Gales shows off a simplified way to pract...
# 199  SM4jCsxM_dM         The 3 EASIEST strum patterns for beginners
#
#                                            description  \
# 0    Are you part of the 90% of aspiring guitarists...
# ...

# %%
# df.to_csv("../data/raw/guitar_sample_csv.csv", index=False)
