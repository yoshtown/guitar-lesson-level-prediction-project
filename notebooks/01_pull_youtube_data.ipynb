# %% [markdown]
# ### Imports & env

# %%
from dotenv import load_dotenv
import os, json, sys

# Get the project root (one level above "notebooks")
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(project_root)

load_dotenv("../.env")
API_KEY = os.environ.get("YOUTUBE_API_KEY")
print("Has key:", bool(API_KEY))
# Out:
# Has key: True

# %% [markdown]
# ### Fetch(small test)

# %%
from src.youtube_fetcher import YouTubeFetcher

f = YouTubeFetcher(api_key=API_KEY)
meta = f.search_and_fetch("guitar chord lesson beginner intermediate advanced", max_results=2000)
len(meta)
# Out:
# INFO:googleapiclient.discovery_cache:file_cache is only supported with oauth2client<4.0.0
# INFO:src.youtube_fetcher:Collected 1/2000 ids
# INFO:src.youtube_fetcher:Collected 2/2000 ids
# INFO:src.youtube_fetcher:Collected 3/2000 ids
# INFO:src.youtube_fetcher:Collected 4/2000 ids
# INFO:src.youtube_fetcher:Collected 5/2000 ids
# INFO:src.youtube_fetcher:Collected 6/2000 ids
# INFO:src.youtube_fetcher:Collected 7/2000 ids
# INFO:src.youtube_fetcher:Collected 8/2000 ids
# INFO:src.youtube_fetcher:Collected 9/2000 ids
# INFO:src.youtube_fetcher:Collected 10/2000 ids
# INFO:src.youtube_fetcher:Collected 11/2000 ids
# INFO:src.youtube_fetcher:Collected 12/2000 ids
# INFO:src.youtube_fetcher:Collected 13/2000 ids
# INFO:src.youtube_fetcher:Collected 14/2000 ids
# INFO:src.youtube_fetcher:Collected 15/2000 ids
# INFO:src.youtube_fetcher:Collected 16/2000 ids
# INFO:src.youtube_fetcher:Collected 17/2000 ids
# INFO:src.youtube_fetcher:Collected 18/2000 ids
# INFO:src.youtube_fetcher:Collected 19/2000 ids
# INFO:src.youtube_fetcher:Collected 20/2000 ids
# INFO:src.youtube_fetcher:Collected 21/2000 ids
# INFO:src.youtube_fetcher:Collected 22/2000 ids
# INFO:src.youtube_fetcher:Collected 23/2000 ids
# INFO:src.youtube_fetcher:Collected 24/2000 ids
# INFO:src.youtube_fetcher:Collected 25/2000 ids
# INFO:src.youtube_fetcher:Collected 26/2000 ids
# INFO:src.youtube_fetcher:Collected 27/2000 ids
# INFO:src.youtube_fetcher:Collected 28/2000 ids
# INFO:src.youtube_fetcher:Collected 29/2000 ids
# INFO:src.youtube_fetcher:Collected 30/2000 ids
# INFO:src.youtube_fetcher:Collected 31/2000 ids
# INFO:src.youtube_fetcher:Collected 32/2000 ids
# INFO:src.youtube_fetcher:Collected 33/2000 ids
# INFO:src.youtube_fetcher:Collected 34/2000 ids
# INFO:src.youtube_fetcher:Collected 35/2000 ids
# INFO:src.youtube_fetcher:Collected 36/2000 ids
# INFO:src.youtube_fetcher:Collected 37/2000 ids
# INFO:src.youtube_fetcher:Collected 38/2000 ids
# INFO:src.youtube_fetcher:Collected 39/2000 ids
# INFO:src.youtube_fetcher:Collected 40/2000 ids
# INFO:src.youtube_fetcher:Collected 41/2000 ids
# INFO:src.youtube_fetcher:Collected 42/2000 ids
# INFO:src.youtube_fetcher:Collected 43/2000 ids
# INFO:src.youtube_fetcher:Collected 44/2000 ids
# INFO:src.youtube_fetcher:Collected 45/2000 ids
# INFO:src.youtube_fetcher:Collected 46/2000 ids
# INFO:src.youtube_fetcher:Collected 47/2000 ids
# INFO:src.youtube_fetcher:Collected 48/2000 ids
# INFO:src.youtube_fetcher:Collected 49/2000 ids
# INFO:src.youtube_fetcher:Collected 50/2000 ids
# INFO:src.youtube_fetcher:Collected 51/2000 ids
# INFO:src.youtube_fetcher:Collected 52/2000 ids
# INFO:src.youtube_fetcher:Collected 53/2000 ids
# INFO:src.youtube_fetcher:Collected 54/2000 ids
# INFO:src.youtube_fetcher:Collected 55/2000 ids
# INFO:src.youtube_fetcher:Collected 56/2000 ids
# INFO:src.youtube_fetcher:Collected 57/2000 ids
# INFO:src.youtube_fetcher:Collected 58/2000 ids
# INFO:src.youtube_fetcher:Collected 59/2000 ids
# INFO:src.youtube_fetcher:Collected 60/2000 ids
# INFO:src.youtube_fetcher:Collected 61/2000 ids
# INFO:src.youtube_fetcher:Collected 62/2000 ids
# INFO:src.youtube_fetcher:Collected 63/2000 ids
# INFO:src.youtube_fetcher:Collected 64/2000 ids
# INFO:src.youtube_fetcher:Collected 65/2000 ids
# INFO:src.youtube_fetcher:Collected 66/2000 ids
# INFO:src.youtube_fetcher:Collected 67/2000 ids
# INFO:src.youtube_fetcher:Collected 68/2000 ids
# INFO:src.youtube_fetcher:Collected 69/2000 ids
# INFO:src.youtube_fetcher:Collected 70/2000 ids
# INFO:src.youtube_fetcher:Collected 71/2000 ids
# INFO:src.youtube_fetcher:Collected 72/2000 ids
# INFO:src.youtube_fetcher:Collected 73/2000 ids
# INFO:src.youtube_fetcher:Collected 74/2000 ids
# INFO:src.youtube_fetcher:Collected 75/2000 ids
# INFO:src.youtube_fetcher:Collected 76/2000 ids
# INFO:src.youtube_fetcher:Collected 77/2000 ids
# INFO:src.youtube_fetcher:Collected 78/2000 ids
# INFO:src.youtube_fetcher:Collected 79/2000 ids
# INFO:src.youtube_fetcher:Collected 80/2000 ids
# INFO:src.youtube_fetcher:Collected 81/2000 ids
# INFO:src.youtube_fetcher:Collected 82/2000 ids
# INFO:src.youtube_fetcher:Collected 83/2000 ids
# INFO:src.youtube_fetcher:Collected 84/2000 ids
# INFO:src.youtube_fetcher:Collected 85/2000 ids
# INFO:src.youtube_fetcher:Collected 86/2000 ids
# INFO:src.youtube_fetcher:Collected 87/2000 ids
# INFO:src.youtube_fetcher:Collected 88/2000 ids
# INFO:src.youtube_fetcher:Collected 89/2000 ids
# INFO:src.youtube_fetcher:Collected 90/2000 ids
# INFO:src.youtube_fetcher:Collected 91/2000 ids
# INFO:src.youtube_fetcher:Collected 92/2000 ids
# INFO:src.youtube_fetcher:Collected 93/2000 ids
# INFO:src.youtube_fetcher:Collected 94/2000 ids
# INFO:src.youtube_fetcher:Collected 95/2000 ids
# INFO:src.youtube_fetcher:Collected 96/2000 ids
# INFO:src.youtube_fetcher:Collected 97/2000 ids
# INFO:src.youtube_fetcher:Collected 98/2000 ids
# INFO:src.youtube_fetcher:Collected 99/2000 ids
# INFO:src.youtube_fetcher:Collected 100/2000 ids
# INFO:src.youtube_fetcher:Collected 101/2000 ids
# INFO:src.youtube_fetcher:Collected 102/2000 ids
# INFO:src.youtube_fetcher:Collected 103/2000 ids
# INFO:src.youtube_fetcher:Collected 104/2000 ids
# INFO:src.youtube_fetcher:Collected 105/2000 ids
# INFO:src.youtube_fetcher:Collected 106/2000 ids
# INFO:src.youtube_fetcher:Collected 107/2000 ids
# INFO:src.youtube_fetcher:Collected 108/2000 ids
# INFO:src.youtube_fetcher:Collected 109/2000 ids
# INFO:src.youtube_fetcher:Collected 110/2000 ids
# INFO:src.youtube_fetcher:Collected 111/2000 ids
# INFO:src.youtube_fetcher:Collected 112/2000 ids
# INFO:src.youtube_fetcher:Collected 113/2000 ids
# INFO:src.youtube_fetcher:Collected 114/2000 ids
# INFO:src.youtube_fetcher:Collected 115/2000 ids
# INFO:src.youtube_fetcher:Collected 116/2000 ids
# INFO:src.youtube_fetcher:Collected 117/2000 ids
# INFO:src.youtube_fetcher:Collected 118/2000 ids
# INFO:src.youtube_fetcher:Collected 119/2000 ids
# INFO:src.youtube_fetcher:Collected 120/2000 ids
# INFO:src.youtube_fetcher:Collected 121/2000 ids
# INFO:src.youtube_fetcher:Collected 122/2000 ids
# INFO:src.youtube_fetcher:Collected 123/2000 ids
# INFO:src.youtube_fetcher:Collected 124/2000 ids
# INFO:src.youtube_fetcher:Collected 125/2000 ids
# INFO:src.youtube_fetcher:Collected 126/2000 ids
# INFO:src.youtube_fetcher:Collected 127/2000 ids
# INFO:src.youtube_fetcher:Collected 128/2000 ids
# INFO:src.youtube_fetcher:Collected 129/2000 ids
# INFO:src.youtube_fetcher:Collected 130/2000 ids
# INFO:src.youtube_fetcher:Collected 131/2000 ids
# INFO:src.youtube_fetcher:Collected 132/2000 ids
# INFO:src.youtube_fetcher:Collected 133/2000 ids
# INFO:src.youtube_fetcher:Collected 134/2000 ids
# INFO:src.youtube_fetcher:Collected 135/2000 ids
# INFO:src.youtube_fetcher:Collected 136/2000 ids
# INFO:src.youtube_fetcher:Collected 137/2000 ids
# INFO:src.youtube_fetcher:Collected 138/2000 ids
# INFO:src.youtube_fetcher:Collected 139/2000 ids
# INFO:src.youtube_fetcher:Collected 140/2000 ids
# INFO:src.youtube_fetcher:Collected 141/2000 ids
# INFO:src.youtube_fetcher:Collected 142/2000 ids
# INFO:src.youtube_fetcher:Collected 143/2000 ids
# INFO:src.youtube_fetcher:Collected 144/2000 ids
# INFO:src.youtube_fetcher:Collected 145/2000 ids
# INFO:src.youtube_fetcher:Collected 146/2000 ids
# INFO:src.youtube_fetcher:Collected 147/2000 ids
# INFO:src.youtube_fetcher:Collected 148/2000 ids
# INFO:src.youtube_fetcher:Collected 149/2000 ids
# INFO:src.youtube_fetcher:Collected 150/2000 ids
# INFO:src.youtube_fetcher:Collected 151/2000 ids
# INFO:src.youtube_fetcher:Collected 152/2000 ids
# INFO:src.youtube_fetcher:Collected 153/2000 ids
# INFO:src.youtube_fetcher:Collected 154/2000 ids
# INFO:src.youtube_fetcher:Collected 155/2000 ids
# INFO:src.youtube_fetcher:Collected 156/2000 ids
# INFO:src.youtube_fetcher:Collected 157/2000 ids
# INFO:src.youtube_fetcher:Collected 158/2000 ids
# INFO:src.youtube_fetcher:Collected 159/2000 ids
# INFO:src.youtube_fetcher:Collected 160/2000 ids
# INFO:src.youtube_fetcher:Collected 161/2000 ids
# INFO:src.youtube_fetcher:Collected 162/2000 ids
# INFO:src.youtube_fetcher:Collected 163/2000 ids
# INFO:src.youtube_fetcher:Collected 164/2000 ids
# INFO:src.youtube_fetcher:Collected 165/2000 ids
# INFO:src.youtube_fetcher:Collected 166/2000 ids
# INFO:src.youtube_fetcher:Collected 167/2000 ids
# INFO:src.youtube_fetcher:Collected 168/2000 ids
# INFO:src.youtube_fetcher:Collected 169/2000 ids
# INFO:src.youtube_fetcher:Collected 170/2000 ids
# INFO:src.youtube_fetcher:Collected 171/2000 ids
# INFO:src.youtube_fetcher:Collected 172/2000 ids
# INFO:src.youtube_fetcher:Collected 173/2000 ids
# INFO:src.youtube_fetcher:Collected 174/2000 ids
# INFO:src.youtube_fetcher:Collected 175/2000 ids
# INFO:src.youtube_fetcher:Collected 176/2000 ids
# INFO:src.youtube_fetcher:Collected 177/2000 ids
# INFO:src.youtube_fetcher:Collected 178/2000 ids
# INFO:src.youtube_fetcher:Collected 179/2000 ids
# INFO:src.youtube_fetcher:Collected 180/2000 ids
# INFO:src.youtube_fetcher:Collected 181/2000 ids
# INFO:src.youtube_fetcher:Collected 182/2000 ids
# INFO:src.youtube_fetcher:Collected 183/2000 ids
# INFO:src.youtube_fetcher:Collected 184/2000 ids
# INFO:src.youtube_fetcher:Collected 185/2000 ids
# INFO:src.youtube_fetcher:Collected 186/2000 ids
# INFO:src.youtube_fetcher:Collected 187/2000 ids
# INFO:src.youtube_fetcher:Collected 188/2000 ids
# INFO:src.youtube_fetcher:Collected 189/2000 ids
# INFO:src.youtube_fetcher:Collected 190/2000 ids
# INFO:src.youtube_fetcher:Collected 191/2000 ids
# INFO:src.youtube_fetcher:Collected 192/2000 ids
# INFO:src.youtube_fetcher:Collected 193/2000 ids
# INFO:src.youtube_fetcher:Collected 194/2000 ids
# INFO:src.youtube_fetcher:Collected 195/2000 ids
# INFO:src.youtube_fetcher:Collected 196/2000 ids
# INFO:src.youtube_fetcher:Collected 197/2000 ids
# INFO:src.youtube_fetcher:Collected 198/2000 ids
# INFO:src.youtube_fetcher:Collected 199/2000 ids
# INFO:src.youtube_fetcher:Collected 200/2000 ids
# INFO:src.youtube_fetcher:Collected 201/2000 ids
# INFO:src.youtube_fetcher:Collected 202/2000 ids
# INFO:src.youtube_fetcher:Collected 203/2000 ids
# INFO:src.youtube_fetcher:Collected 204/2000 ids
# INFO:src.youtube_fetcher:Collected 205/2000 ids
# INFO:src.youtube_fetcher:Collected 206/2000 ids
# INFO:src.youtube_fetcher:Collected 207/2000 ids
# INFO:src.youtube_fetcher:Collected 208/2000 ids
# INFO:src.youtube_fetcher:Collected 209/2000 ids
# INFO:src.youtube_fetcher:Collected 210/2000 ids
# INFO:src.youtube_fetcher:Collected 211/2000 ids
# INFO:src.youtube_fetcher:Collected 212/2000 ids
# INFO:src.youtube_fetcher:Collected 213/2000 ids
# INFO:src.youtube_fetcher:Collected 214/2000 ids
# INFO:src.youtube_fetcher:Collected 215/2000 ids
# INFO:src.youtube_fetcher:Collected 216/2000 ids
# INFO:src.youtube_fetcher:Collected 217/2000 ids
# INFO:src.youtube_fetcher:Collected 218/2000 ids
# INFO:src.youtube_fetcher:Collected 219/2000 ids
# INFO:src.youtube_fetcher:Collected 220/2000 ids
# INFO:src.youtube_fetcher:Collected 221/2000 ids
# INFO:src.youtube_fetcher:Collected 222/2000 ids
# INFO:src.youtube_fetcher:Collected 223/2000 ids
# INFO:src.youtube_fetcher:Collected 224/2000 ids
# INFO:src.youtube_fetcher:Collected 225/2000 ids
# INFO:src.youtube_fetcher:Collected 226/2000 ids
# INFO:src.youtube_fetcher:Collected 227/2000 ids
# INFO:src.youtube_fetcher:Collected 228/2000 ids
# INFO:src.youtube_fetcher:Collected 229/2000 ids
# INFO:src.youtube_fetcher:Collected 230/2000 ids
# INFO:src.youtube_fetcher:Collected 231/2000 ids
# INFO:src.youtube_fetcher:Collected 232/2000 ids
# INFO:src.youtube_fetcher:Collected 233/2000 ids
# INFO:src.youtube_fetcher:Collected 234/2000 ids
# INFO:src.youtube_fetcher:Collected 235/2000 ids
# INFO:src.youtube_fetcher:Collected 236/2000 ids
# INFO:src.youtube_fetcher:Collected 237/2000 ids
# INFO:src.youtube_fetcher:Collected 238/2000 ids
# INFO:src.youtube_fetcher:Collected 239/2000 ids
# INFO:src.youtube_fetcher:Collected 240/2000 ids
# INFO:src.youtube_fetcher:Collected 241/2000 ids
# INFO:src.youtube_fetcher:Collected 242/2000 ids
# INFO:src.youtube_fetcher:Collected 243/2000 ids
# INFO:src.youtube_fetcher:Collected 244/2000 ids
# INFO:src.youtube_fetcher:Collected 245/2000 ids
# INFO:src.youtube_fetcher:Collected 246/2000 ids
# INFO:src.youtube_fetcher:Collected 247/2000 ids
# INFO:src.youtube_fetcher:Collected 248/2000 ids
# INFO:src.youtube_fetcher:Collected 249/2000 ids
# INFO:src.youtube_fetcher:Collected 250/2000 ids
# INFO:src.youtube_fetcher:Collected 251/2000 ids
# INFO:src.youtube_fetcher:Collected 252/2000 ids
# INFO:src.youtube_fetcher:Collected 253/2000 ids
# INFO:src.youtube_fetcher:Collected 254/2000 ids
# INFO:src.youtube_fetcher:Collected 255/2000 ids
# INFO:src.youtube_fetcher:Collected 256/2000 ids
# INFO:src.youtube_fetcher:Collected 257/2000 ids
# INFO:src.youtube_fetcher:Collected 258/2000 ids
# INFO:src.youtube_fetcher:Collected 259/2000 ids
# INFO:src.youtube_fetcher:Collected 260/2000 ids
# INFO:src.youtube_fetcher:Collected 261/2000 ids
# INFO:src.youtube_fetcher:Collected 262/2000 ids
# INFO:src.youtube_fetcher:Collected 263/2000 ids
# INFO:src.youtube_fetcher:Collected 264/2000 ids
# INFO:src.youtube_fetcher:Collected 265/2000 ids
# INFO:src.youtube_fetcher:Collected 266/2000 ids
# INFO:src.youtube_fetcher:Collected 267/2000 ids
# INFO:src.youtube_fetcher:Collected 268/2000 ids
# INFO:src.youtube_fetcher:Collected 269/2000 ids
# INFO:src.youtube_fetcher:Collected 270/2000 ids
# INFO:src.youtube_fetcher:Collected 271/2000 ids
# INFO:src.youtube_fetcher:Collected 272/2000 ids
# INFO:src.youtube_fetcher:Collected 273/2000 ids
# INFO:src.youtube_fetcher:Collected 274/2000 ids
# INFO:src.youtube_fetcher:Collected 275/2000 ids
# INFO:src.youtube_fetcher:Collected 276/2000 ids
# INFO:src.youtube_fetcher:Collected 277/2000 ids
# INFO:src.youtube_fetcher:Collected 278/2000 ids
# INFO:src.youtube_fetcher:Collected 279/2000 ids
# INFO:src.youtube_fetcher:Collected 280/2000 ids
# INFO:src.youtube_fetcher:Collected 281/2000 ids
# INFO:src.youtube_fetcher:Collected 282/2000 ids
# INFO:src.youtube_fetcher:Collected 283/2000 ids
# INFO:src.youtube_fetcher:Collected 284/2000 ids
# INFO:src.youtube_fetcher:Collected 285/2000 ids
# INFO:src.youtube_fetcher:Collected 286/2000 ids
# INFO:src.youtube_fetcher:Collected 287/2000 ids
# INFO:src.youtube_fetcher:Collected 288/2000 ids
# INFO:src.youtube_fetcher:Collected 289/2000 ids
# INFO:src.youtube_fetcher:Collected 290/2000 ids
# INFO:src.youtube_fetcher:Collected 291/2000 ids
# INFO:src.youtube_fetcher:Collected 292/2000 ids
# INFO:src.youtube_fetcher:Collected 293/2000 ids
# INFO:src.youtube_fetcher:Collected 294/2000 ids
# INFO:src.youtube_fetcher:Collected 295/2000 ids
# INFO:src.youtube_fetcher:Collected 296/2000 ids
# INFO:src.youtube_fetcher:Collected 297/2000 ids
# INFO:src.youtube_fetcher:Collected 298/2000 ids
# INFO:src.youtube_fetcher:Collected 299/2000 ids
# INFO:src.youtube_fetcher:Collected 300/2000 ids
# INFO:src.youtube_fetcher:Collected 301/2000 ids
# INFO:src.youtube_fetcher:Collected 302/2000 ids
# INFO:src.youtube_fetcher:Collected 303/2000 ids
# INFO:src.youtube_fetcher:Collected 304/2000 ids
# INFO:src.youtube_fetcher:Collected 305/2000 ids
# INFO:src.youtube_fetcher:Collected 306/2000 ids
# INFO:src.youtube_fetcher:Collected 307/2000 ids
# INFO:src.youtube_fetcher:Collected 308/2000 ids
# INFO:src.youtube_fetcher:Collected 309/2000 ids
# INFO:src.youtube_fetcher:Collected 310/2000 ids
# INFO:src.youtube_fetcher:Collected 311/2000 ids
# INFO:src.youtube_fetcher:Collected 312/2000 ids
# INFO:src.youtube_fetcher:Collected 313/2000 ids
# INFO:src.youtube_fetcher:Collected 314/2000 ids
# INFO:src.youtube_fetcher:Collected 315/2000 ids
# INFO:src.youtube_fetcher:Collected 316/2000 ids
# INFO:src.youtube_fetcher:Collected 317/2000 ids
# INFO:src.youtube_fetcher:Collected 318/2000 ids
# INFO:src.youtube_fetcher:Collected 319/2000 ids
# INFO:src.youtube_fetcher:Collected 320/2000 ids
# INFO:src.youtube_fetcher:Collected 321/2000 ids
# INFO:src.youtube_fetcher:Collected 322/2000 ids
# INFO:src.youtube_fetcher:Collected 323/2000 ids
# INFO:src.youtube_fetcher:Collected 324/2000 ids
# INFO:src.youtube_fetcher:Collected 325/2000 ids
# INFO:src.youtube_fetcher:Collected 326/2000 ids
# INFO:src.youtube_fetcher:Collected 327/2000 ids
# INFO:src.youtube_fetcher:Collected 328/2000 ids
# INFO:src.youtube_fetcher:Collected 329/2000 ids
# INFO:src.youtube_fetcher:Collected 330/2000 ids
# INFO:src.youtube_fetcher:Collected 331/2000 ids
# INFO:src.youtube_fetcher:Collected 332/2000 ids
# INFO:src.youtube_fetcher:Collected 333/2000 ids
# INFO:src.youtube_fetcher:Collected 334/2000 ids
# INFO:src.youtube_fetcher:Collected 335/2000 ids
# INFO:src.youtube_fetcher:Collected 336/2000 ids
# INFO:src.youtube_fetcher:Collected 337/2000 ids
# INFO:src.youtube_fetcher:Collected 338/2000 ids
# INFO:src.youtube_fetcher:Collected 339/2000 ids
# INFO:src.youtube_fetcher:Collected 340/2000 ids
# INFO:src.youtube_fetcher:Collected 341/2000 ids
# INFO:src.youtube_fetcher:Collected 342/2000 ids
# INFO:src.youtube_fetcher:Collected 343/2000 ids
# INFO:src.youtube_fetcher:Collected 344/2000 ids
# INFO:src.youtube_fetcher:Collected 345/2000 ids
# INFO:src.youtube_fetcher:Collected 346/2000 ids
# INFO:src.youtube_fetcher:Collected 347/2000 ids
# INFO:src.youtube_fetcher:Collected 348/2000 ids
# INFO:src.youtube_fetcher:Collected 349/2000 ids
# INFO:src.youtube_fetcher:Collected 350/2000 ids
# INFO:src.youtube_fetcher:Collected 351/2000 ids
# INFO:src.youtube_fetcher:Collected 352/2000 ids
# INFO:src.youtube_fetcher:Collected 353/2000 ids
# INFO:src.youtube_fetcher:Collected 354/2000 ids
# INFO:src.youtube_fetcher:Collected 355/2000 ids
# INFO:src.youtube_fetcher:Collected 356/2000 ids
# INFO:src.youtube_fetcher:Collected 357/2000 ids
# INFO:src.youtube_fetcher:Collected 358/2000 ids
# INFO:src.youtube_fetcher:Collected 359/2000 ids
# INFO:src.youtube_fetcher:Collected 360/2000 ids
# INFO:src.youtube_fetcher:Collected 361/2000 ids
# INFO:src.youtube_fetcher:Collected 362/2000 ids
# INFO:src.youtube_fetcher:Collected 363/2000 ids
# INFO:src.youtube_fetcher:Collected 364/2000 ids
# INFO:src.youtube_fetcher:Collected 365/2000 ids
# INFO:src.youtube_fetcher:Collected 366/2000 ids
# INFO:src.youtube_fetcher:Collected 367/2000 ids
# INFO:src.youtube_fetcher:Collected 368/2000 ids
# INFO:src.youtube_fetcher:Collected 369/2000 ids
# INFO:src.youtube_fetcher:Collected 370/2000 ids
# INFO:src.youtube_fetcher:Collected 371/2000 ids
# INFO:src.youtube_fetcher:Collected 372/2000 ids
# INFO:src.youtube_fetcher:Collected 373/2000 ids
# INFO:src.youtube_fetcher:Collected 374/2000 ids
# INFO:src.youtube_fetcher:Collected 375/2000 ids
# INFO:src.youtube_fetcher:Collected 376/2000 ids
# INFO:src.youtube_fetcher:Collected 377/2000 ids
# INFO:src.youtube_fetcher:Collected 378/2000 ids
# INFO:src.youtube_fetcher:Collected 379/2000 ids
# INFO:src.youtube_fetcher:Collected 380/2000 ids
# INFO:src.youtube_fetcher:Collected 381/2000 ids
# INFO:src.youtube_fetcher:Collected 382/2000 ids
# INFO:src.youtube_fetcher:Collected 383/2000 ids
# INFO:src.youtube_fetcher:Collected 384/2000 ids
# INFO:src.youtube_fetcher:Collected 385/2000 ids
# INFO:src.youtube_fetcher:Collected 386/2000 ids
# INFO:src.youtube_fetcher:Collected 387/2000 ids
# INFO:src.youtube_fetcher:Collected 388/2000 ids
# INFO:src.youtube_fetcher:Collected 389/2000 ids
# INFO:src.youtube_fetcher:Collected 390/2000 ids
# INFO:src.youtube_fetcher:Collected 391/2000 ids
# INFO:src.youtube_fetcher:Collected 392/2000 ids
# INFO:src.youtube_fetcher:Collected 393/2000 ids
# INFO:src.youtube_fetcher:Collected 394/2000 ids
# INFO:src.youtube_fetcher:Collected 395/2000 ids
# INFO:src.youtube_fetcher:Collected 396/2000 ids
# INFO:src.youtube_fetcher:Collected 397/2000 ids
# INFO:src.youtube_fetcher:Collected 398/2000 ids
# INFO:src.youtube_fetcher:Collected 399/2000 ids
# INFO:src.youtube_fetcher:Collected 400/2000 ids
# INFO:src.youtube_fetcher:Collected 401/2000 ids
# INFO:src.youtube_fetcher:Collected 402/2000 ids
# INFO:src.youtube_fetcher:Collected 403/2000 ids
# INFO:src.youtube_fetcher:Collected 404/2000 ids
# INFO:src.youtube_fetcher:Collected 405/2000 ids
# INFO:src.youtube_fetcher:Collected 406/2000 ids
# INFO:src.youtube_fetcher:Collected 407/2000 ids
# INFO:src.youtube_fetcher:Collected 408/2000 ids
# INFO:src.youtube_fetcher:Collected 409/2000 ids
# INFO:src.youtube_fetcher:Collected 410/2000 ids
# INFO:src.youtube_fetcher:Collected 411/2000 ids
# INFO:src.youtube_fetcher:Collected 412/2000 ids
# INFO:src.youtube_fetcher:Collected 413/2000 ids
# INFO:src.youtube_fetcher:Collected 414/2000 ids
# INFO:src.youtube_fetcher:Collected 415/2000 ids
# INFO:src.youtube_fetcher:Collected 416/2000 ids
# INFO:src.youtube_fetcher:Collected 417/2000 ids
# INFO:src.youtube_fetcher:Collected 418/2000 ids
# INFO:src.youtube_fetcher:Collected 419/2000 ids
# INFO:src.youtube_fetcher:Collected 420/2000 ids
# INFO:src.youtube_fetcher:Collected 421/2000 ids
# INFO:src.youtube_fetcher:Collected 422/2000 ids
# INFO:src.youtube_fetcher:Collected 423/2000 ids
# INFO:src.youtube_fetcher:Collected 424/2000 ids
# INFO:src.youtube_fetcher:Collected 425/2000 ids
# INFO:src.youtube_fetcher:Collected 426/2000 ids
# INFO:src.youtube_fetcher:Collected 427/2000 ids
# INFO:src.youtube_fetcher:Collected 428/2000 ids
# INFO:src.youtube_fetcher:Collected 429/2000 ids
# INFO:src.youtube_fetcher:Collected 430/2000 ids
# INFO:src.youtube_fetcher:Collected 431/2000 ids
# INFO:src.youtube_fetcher:Collected 432/2000 ids
# INFO:src.youtube_fetcher:Collected 433/2000 ids
# INFO:src.youtube_fetcher:Collected 434/2000 ids
# INFO:src.youtube_fetcher:Collected 435/2000 ids
# INFO:src.youtube_fetcher:Collected 436/2000 ids
# INFO:src.youtube_fetcher:Collected 437/2000 ids
# INFO:src.youtube_fetcher:Collected 438/2000 ids
# INFO:src.youtube_fetcher:Collected 439/2000 ids
# INFO:src.youtube_fetcher:Collected 440/2000 ids
# INFO:src.youtube_fetcher:Collected 441/2000 ids
# INFO:src.youtube_fetcher:Collected 442/2000 ids
# INFO:src.youtube_fetcher:Collected 443/2000 ids
# INFO:src.youtube_fetcher:Collected 444/2000 ids
# INFO:src.youtube_fetcher:Collected 445/2000 ids
# INFO:src.youtube_fetcher:Collected 446/2000 ids
# INFO:src.youtube_fetcher:Collected 447/2000 ids
# INFO:src.youtube_fetcher:Collected 448/2000 ids
# INFO:src.youtube_fetcher:Collected 449/2000 ids
# INFO:src.youtube_fetcher:Collected 450/2000 ids
# INFO:src.youtube_fetcher:Collected 451/2000 ids
# INFO:src.youtube_fetcher:Collected 452/2000 ids
# INFO:src.youtube_fetcher:Collected 453/2000 ids
# INFO:src.youtube_fetcher:Collected 454/2000 ids
# INFO:src.youtube_fetcher:Collected 455/2000 ids
# INFO:src.youtube_fetcher:Collected 456/2000 ids
# INFO:src.youtube_fetcher:Collected 457/2000 ids
# INFO:src.youtube_fetcher:Collected 458/2000 ids
# INFO:src.youtube_fetcher:Collected 459/2000 ids
# INFO:src.youtube_fetcher:Collected 460/2000 ids
# INFO:src.youtube_fetcher:Collected 461/2000 ids
# INFO:src.youtube_fetcher:Collected 462/2000 ids
# INFO:src.youtube_fetcher:Collected 463/2000 ids
# INFO:src.youtube_fetcher:Collected 464/2000 ids
# INFO:src.youtube_fetcher:Collected 465/2000 ids
# INFO:src.youtube_fetcher:Collected 466/2000 ids
# INFO:src.youtube_fetcher:Collected 467/2000 ids
# INFO:src.youtube_fetcher:Collected 468/2000 ids
# INFO:src.youtube_fetcher:Collected 469/2000 ids
# INFO:src.youtube_fetcher:Collected 470/2000 ids
# INFO:src.youtube_fetcher:Collected 471/2000 ids
# INFO:src.youtube_fetcher:Collected 472/2000 ids
# INFO:src.youtube_fetcher:Collected 473/2000 ids
# INFO:src.youtube_fetcher:Collected 474/2000 ids
# INFO:src.youtube_fetcher:Collected 475/2000 ids
# INFO:src.youtube_fetcher:Collected 476/2000 ids
# INFO:src.youtube_fetcher:Collected 477/2000 ids
# INFO:src.youtube_fetcher:Collected 478/2000 ids
# INFO:src.youtube_fetcher:Collected 479/2000 ids
# INFO:src.youtube_fetcher:Collected 480/2000 ids
# INFO:src.youtube_fetcher:Collected 481/2000 ids
# INFO:src.youtube_fetcher:Collected 482/2000 ids
# INFO:src.youtube_fetcher:Collected 483/2000 ids
# INFO:src.youtube_fetcher:Collected 484/2000 ids
# INFO:src.youtube_fetcher:Collected 485/2000 ids
# INFO:src.youtube_fetcher:Collected 486/2000 ids
# INFO:src.youtube_fetcher:Collected 487/2000 ids
# INFO:src.youtube_fetcher:Collected 488/2000 ids
# INFO:src.youtube_fetcher:Collected 489/2000 ids
# INFO:src.youtube_fetcher:Collected 490/2000 ids
# INFO:src.youtube_fetcher:Collected 491/2000 ids
# INFO:src.youtube_fetcher:Collected 492/2000 ids
# INFO:src.youtube_fetcher:Collected 493/2000 ids
# INFO:src.youtube_fetcher:Collected 494/2000 ids
# INFO:src.youtube_fetcher:Collected 495/2000 ids
# INFO:src.youtube_fetcher:Collected 496/2000 ids
# INFO:src.youtube_fetcher:Collected 497/2000 ids
# INFO:src.youtube_fetcher:Collected 498/2000 ids
# INFO:src.youtube_fetcher:Collected 499/2000 ids
# INFO:src.youtube_fetcher:Collected 500/2000 ids
# INFO:src.youtube_fetcher:Collected 501/2000 ids
# INFO:src.youtube_fetcher:Collected 502/2000 ids
# INFO:src.youtube_fetcher:Collected 503/2000 ids
# INFO:src.youtube_fetcher:Collected 504/2000 ids
# INFO:src.youtube_fetcher:Collected 505/2000 ids
# INFO:src.youtube_fetcher:Collected 506/2000 ids
# INFO:src.youtube_fetcher:Collected 507/2000 ids
# INFO:src.youtube_fetcher:Collected 508/2000 ids
# INFO:src.youtube_fetcher:Collected 509/2000 ids
# INFO:src.youtube_fetcher:Collected 510/2000 ids
# INFO:src.youtube_fetcher:Collected 511/2000 ids
# INFO:src.youtube_fetcher:Collected 512/2000 ids
# INFO:src.youtube_fetcher:Collected 513/2000 ids
# INFO:src.youtube_fetcher:Collected 514/2000 ids
# INFO:src.youtube_fetcher:Collected 515/2000 ids
# INFO:src.youtube_fetcher:Collected 516/2000 ids
# INFO:src.youtube_fetcher:Collected 517/2000 ids
# INFO:src.youtube_fetcher:Collected 518/2000 ids
# INFO:src.youtube_fetcher:Collected 519/2000 ids
# INFO:src.youtube_fetcher:Collected 520/2000 ids
# INFO:src.youtube_fetcher:Collected 521/2000 ids
# INFO:src.youtube_fetcher:Collected 522/2000 ids
# INFO:src.youtube_fetcher:Collected 523/2000 ids
# INFO:src.youtube_fetcher:Collected 524/2000 ids
# INFO:src.youtube_fetcher:Collected 525/2000 ids
# INFO:src.youtube_fetcher:Collected 526/2000 ids
# INFO:src.youtube_fetcher:Collected 527/2000 ids
# INFO:src.youtube_fetcher:Collected 528/2000 ids
# INFO:src.youtube_fetcher:Collected 529/2000 ids
# INFO:src.youtube_fetcher:Collected 530/2000 ids
# INFO:src.youtube_fetcher:Collected 531/2000 ids
# INFO:src.youtube_fetcher:Collected 532/2000 ids
# INFO:src.youtube_fetcher:Collected 533/2000 ids
# INFO:src.youtube_fetcher:Collected 534/2000 ids
# INFO:src.youtube_fetcher:Collected 535/2000 ids
# INFO:src.youtube_fetcher:Collected 536/2000 ids
# INFO:src.youtube_fetcher:Collected 537/2000 ids
# INFO:src.youtube_fetcher:Collected 538/2000 ids
# INFO:src.youtube_fetcher:Collected 539/2000 ids
# INFO:src.youtube_fetcher:Collected 540/2000 ids
# INFO:src.youtube_fetcher:Collected 541/2000 ids
# INFO:src.youtube_fetcher:Collected 542/2000 ids
# INFO:src.youtube_fetcher:Collected 543/2000 ids
# INFO:src.youtube_fetcher:Collected 544/2000 ids
# INFO:src.youtube_fetcher:Collected 545/2000 ids
# INFO:src.youtube_fetcher:Collected 546/2000 ids
# INFO:src.youtube_fetcher:Collected 547/2000 ids
# INFO:src.youtube_fetcher:Collected 548/2000 ids
# INFO:src.youtube_fetcher:Collected 549/2000 ids
# INFO:src.youtube_fetcher:Collected 550/2000 ids
# INFO:src.youtube_fetcher:Collected 551/2000 ids
# INFO:src.youtube_fetcher:Collected 552/2000 ids
# INFO:src.youtube_fetcher:Collected 553/2000 ids
# INFO:src.youtube_fetcher:Collected 554/2000 ids
# INFO:src.youtube_fetcher:Collected 555/2000 ids
# INFO:src.youtube_fetcher:Collected 556/2000 ids
# INFO:src.youtube_fetcher:Collected 557/2000 ids
# INFO:src.youtube_fetcher:Collected 558/2000 ids
# INFO:src.youtube_fetcher:Collected 559/2000 ids
# INFO:src.youtube_fetcher:Collected 560/2000 ids
# INFO:src.youtube_fetcher:Collected 561/2000 ids
# INFO:src.youtube_fetcher:Collected 562/2000 ids
# INFO:src.youtube_fetcher:Collected 563/2000 ids
# INFO:src.youtube_fetcher:Collected 564/2000 ids
# INFO:src.youtube_fetcher:Collected 565/2000 ids
# INFO:src.youtube_fetcher:Collected 566/2000 ids
# INFO:src.youtube_fetcher:Collected 567/2000 ids
# INFO:src.youtube_fetcher:Collected 568/2000 ids
# INFO:src.youtube_fetcher:Collected 569/2000 ids
# INFO:src.youtube_fetcher:Collected 570/2000 ids
# INFO:src.youtube_fetcher:Collected 571/2000 ids
# INFO:src.youtube_fetcher:Collected 572/2000 ids
# INFO:src.youtube_fetcher:Collected 573/2000 ids
# INFO:src.youtube_fetcher:Collected 574/2000 ids
# INFO:src.youtube_fetcher:Collected 575/2000 ids
# INFO:src.youtube_fetcher:Collected 576/2000 ids
# INFO:src.youtube_fetcher:Collected 577/2000 ids
# INFO:src.youtube_fetcher:Collected 578/2000 ids
# INFO:src.youtube_fetcher:Collected 579/2000 ids
# INFO:src.youtube_fetcher:Collected 580/2000 ids
# INFO:src.youtube_fetcher:Collected 581/2000 ids
# INFO:src.youtube_fetcher:Collected 582/2000 ids
# INFO:src.youtube_fetcher:Collected 583/2000 ids
# INFO:src.youtube_fetcher:Collected 584/2000 ids
# INFO:src.youtube_fetcher:Collected 585/2000 ids
# INFO:src.youtube_fetcher:Collected 586/2000 ids
# INFO:src.youtube_fetcher:Collected 587/2000 ids
# INFO:src.youtube_fetcher:Collected 588/2000 ids
# INFO:src.youtube_fetcher:Collected 589/2000 ids
# INFO:src.youtube_fetcher:Collected 590/2000 ids
# INFO:src.youtube_fetcher:Collected 591/2000 ids
# INFO:src.youtube_fetcher:Collected 592/2000 ids
# INFO:src.youtube_fetcher:Collected 593/2000 ids
# INFO:src.youtube_fetcher:Collected 594/2000 ids
# INFO:src.youtube_fetcher:Collected 595/2000 ids
# INFO:src.youtube_fetcher:Collected 596/2000 ids
# INFO:src.youtube_fetcher:Collected 597/2000 ids
# INFO:src.youtube_fetcher:Collected 598/2000 ids
# INFO:src.youtube_fetcher:Collected 599/2000 ids
# INFO:src.youtube_fetcher:Collected 600/2000 ids
# INFO:src.youtube_fetcher:Collected 601/2000 ids
# INFO:src.youtube_fetcher:Collected 602/2000 ids
# INFO:src.youtube_fetcher:Collected 603/2000 ids
# INFO:src.youtube_fetcher:Collected 604/2000 ids
# INFO:src.youtube_fetcher:Collected 605/2000 ids
# INFO:src.youtube_fetcher:Collected 606/2000 ids
# INFO:src.youtube_fetcher:Collected 607/2000 ids
# INFO:src.youtube_fetcher:Collected 608/2000 ids
# INFO:src.youtube_fetcher:Collected 609/2000 ids
# INFO:src.youtube_fetcher:Collected 610/2000 ids
# INFO:src.youtube_fetcher:Collected 611/2000 ids
# INFO:src.youtube_fetcher:Collected 612/2000 ids
# INFO:src.youtube_fetcher:Collected 613/2000 ids
# INFO:src.youtube_fetcher:Collected 614/2000 ids
# INFO:src.youtube_fetcher:Collected 615/2000 ids
# INFO:src.youtube_fetcher:Collected 616/2000 ids
# INFO:src.youtube_fetcher:Collected 617/2000 ids
# INFO:src.youtube_fetcher:Collected 618/2000 ids
# INFO:src.youtube_fetcher:Collected 619/2000 ids
# INFO:src.youtube_fetcher:Collected 620/2000 ids
# INFO:src.youtube_fetcher:Collected 621/2000 ids
# INFO:src.youtube_fetcher:Collected 622/2000 ids
# INFO:src.youtube_fetcher:Collected 623/2000 ids
# INFO:src.youtube_fetcher:Collected 624/2000 ids
# INFO:src.youtube_fetcher:Collected 625/2000 ids
# INFO:src.youtube_fetcher:Collected 626/2000 ids
# INFO:src.youtube_fetcher:Collected 627/2000 ids
# INFO:src.youtube_fetcher:Collected 628/2000 ids
# INFO:src.youtube_fetcher:Collected 629/2000 ids
# INFO:src.youtube_fetcher:Collected 630/2000 ids
# INFO:src.youtube_fetcher:Collected 631/2000 ids
# INFO:src.youtube_fetcher:Collected 632/2000 ids
# INFO:src.youtube_fetcher:Collected 633/2000 ids
# INFO:src.youtube_fetcher:Collected 634/2000 ids
# INFO:src.youtube_fetcher:Collected 635/2000 ids
# INFO:src.youtube_fetcher:Collected 636/2000 ids
# INFO:src.youtube_fetcher:Collected 637/2000 ids
# INFO:src.youtube_fetcher:Collected 638/2000 ids
# INFO:src.youtube_fetcher:Collected 639/2000 ids
# INFO:src.youtube_fetcher:Collected 640/2000 ids
# INFO:src.youtube_fetcher:Collected 641/2000 ids
# INFO:src.youtube_fetcher:Collected 642/2000 ids
# INFO:src.youtube_fetcher:Collected 643/2000 ids
# INFO:src.youtube_fetcher:Collected 644/2000 ids
# INFO:src.youtube_fetcher:Collected 645/2000 ids
# INFO:src.youtube_fetcher:Collected 646/2000 ids
# INFO:src.youtube_fetcher:Collected 647/2000 ids
# INFO:src.youtube_fetcher:Collected 648/2000 ids
# INFO:src.youtube_fetcher:Collected 649/2000 ids
# INFO:src.youtube_fetcher:Collected 650/2000 ids
# INFO:src.youtube_fetcher:Collected 651/2000 ids
# INFO:src.youtube_fetcher:Collected 652/2000 ids
# INFO:src.youtube_fetcher:Collected 653/2000 ids
# INFO:src.youtube_fetcher:Collected 654/2000 ids
# INFO:src.youtube_fetcher:Collected 655/2000 ids
# INFO:src.youtube_fetcher:Collected 656/2000 ids
# INFO:src.youtube_fetcher:Collected 657/2000 ids
# INFO:src.youtube_fetcher:Collected 658/2000 ids
# INFO:src.youtube_fetcher:Collected 659/2000 ids
# INFO:src.youtube_fetcher:Collected 660/2000 ids
# INFO:src.youtube_fetcher:Collected 661/2000 ids
# INFO:src.youtube_fetcher:Collected 662/2000 ids
# INFO:src.youtube_fetcher:Collected 663/2000 ids
# INFO:src.youtube_fetcher:Collected 664/2000 ids
# INFO:src.youtube_fetcher:Collected 665/2000 ids
# INFO:src.youtube_fetcher:Collected 666/2000 ids
# INFO:src.youtube_fetcher:Collected 667/2000 ids
# INFO:src.youtube_fetcher:Collected 668/2000 ids
# INFO:src.youtube_fetcher:Collected 669/2000 ids
# INFO:src.youtube_fetcher:Collected 670/2000 ids
# INFO:src.youtube_fetcher:Collected 671/2000 ids
# INFO:src.youtube_fetcher:Collected 672/2000 ids
# INFO:src.youtube_fetcher:Collected 673/2000 ids
# INFO:src.youtube_fetcher:Collected 674/2000 ids
# INFO:src.youtube_fetcher:Collected 675/2000 ids
# INFO:src.youtube_fetcher:Collected 676/2000 ids
# INFO:src.youtube_fetcher:Collected 677/2000 ids
# INFO:src.youtube_fetcher:Collected 678/2000 ids
# INFO:src.youtube_fetcher:Collected 679/2000 ids
# INFO:src.youtube_fetcher:Collected 680/2000 ids
# INFO:src.youtube_fetcher:Collected 681/2000 ids
# INFO:src.youtube_fetcher:Collected 682/2000 ids
# INFO:src.youtube_fetcher:Collected 683/2000 ids
# INFO:src.youtube_fetcher:Collected 684/2000 ids
# INFO:src.youtube_fetcher:Collected 685/2000 ids
# INFO:src.youtube_fetcher:Collected 686/2000 ids
# INFO:src.youtube_fetcher:Collected 687/2000 ids
# INFO:src.youtube_fetcher:Collected 688/2000 ids
# INFO:src.youtube_fetcher:Collected 689/2000 ids
# INFO:src.youtube_fetcher:Collected 690/2000 ids
# INFO:src.youtube_fetcher:Collected 691/2000 ids
# INFO:src.youtube_fetcher:Collected 692/2000 ids
# INFO:src.youtube_fetcher:Collected 693/2000 ids
# INFO:src.youtube_fetcher:Collected 694/2000 ids
# INFO:src.youtube_fetcher:Collected 695/2000 ids
# INFO:src.youtube_fetcher:Collected 696/2000 ids
# INFO:src.youtube_fetcher:Collected 697/2000 ids
# INFO:src.youtube_fetcher:Collected 698/2000 ids
# INFO:src.youtube_fetcher:Collected 699/2000 ids
# INFO:src.youtube_fetcher:Collected 700/2000 ids
# INFO:src.youtube_fetcher:Collected 701/2000 ids
# INFO:src.youtube_fetcher:Collected 702/2000 ids
# INFO:src.youtube_fetcher:Collected 703/2000 ids
# INFO:src.youtube_fetcher:Collected 704/2000 ids
# INFO:src.youtube_fetcher:Collected 705/2000 ids
# INFO:src.youtube_fetcher:Collected 706/2000 ids
# INFO:src.youtube_fetcher:Collected 707/2000 ids
# INFO:src.youtube_fetcher:Collected 708/2000 ids
# INFO:src.youtube_fetcher:Collected 709/2000 ids
# INFO:src.youtube_fetcher:Collected 710/2000 ids
# INFO:src.youtube_fetcher:Collected 711/2000 ids
# INFO:src.youtube_fetcher:Collected 712/2000 ids
# INFO:src.youtube_fetcher:Collected 713/2000 ids
# INFO:src.youtube_fetcher:Collected 714/2000 ids
# INFO:src.youtube_fetcher:Collected 715/2000 ids
# INFO:src.youtube_fetcher:Collected 716/2000 ids
# INFO:src.youtube_fetcher:Collected 717/2000 ids
# INFO:src.youtube_fetcher:Collected 718/2000 ids
# INFO:src.youtube_fetcher:Collected 719/2000 ids
# INFO:src.youtube_fetcher:Collected 720/2000 ids
# INFO:src.youtube_fetcher:Collected 721/2000 ids
# INFO:src.youtube_fetcher:Collected 722/2000 ids
# INFO:src.youtube_fetcher:Collected 723/2000 ids
# INFO:src.youtube_fetcher:Collected 724/2000 ids
# INFO:src.youtube_fetcher:Collected 725/2000 ids
# INFO:src.youtube_fetcher:Collected 726/2000 ids
# INFO:src.youtube_fetcher:Collected 727/2000 ids
# INFO:src.youtube_fetcher:Collected 728/2000 ids
# INFO:src.youtube_fetcher:Collected 729/2000 ids
# INFO:src.youtube_fetcher:Collected 730/2000 ids
# INFO:src.youtube_fetcher:Collected 731/2000 ids
# INFO:src.youtube_fetcher:Collected 732/2000 ids
# INFO:src.youtube_fetcher:Collected 733/2000 ids
# INFO:src.youtube_fetcher:Collected 734/2000 ids
# INFO:src.youtube_fetcher:Collected 735/2000 ids
# INFO:src.youtube_fetcher:Collected 736/2000 ids
# INFO:src.youtube_fetcher:Collected 737/2000 ids
# INFO:src.youtube_fetcher:Collected 738/2000 ids
# INFO:src.youtube_fetcher:Collected 739/2000 ids
# INFO:src.youtube_fetcher:Collected 740/2000 ids
# INFO:src.youtube_fetcher:Collected 741/2000 ids
# INFO:src.youtube_fetcher:Collected 742/2000 ids
# INFO:src.youtube_fetcher:Collected 743/2000 ids
# INFO:src.youtube_fetcher:Collected 744/2000 ids
# INFO:src.youtube_fetcher:Collected 745/2000 ids
# INFO:src.youtube_fetcher:Collected 746/2000 ids
# INFO:src.youtube_fetcher:Collected 747/2000 ids
# INFO:src.youtube_fetcher:Collected 748/2000 ids
# INFO:src.youtube_fetcher:Collected 749/2000 ids
# INFO:src.youtube_fetcher:Collected 750/2000 ids
# INFO:src.youtube_fetcher:Collected 751/2000 ids
# INFO:src.youtube_fetcher:Collected 752/2000 ids
# INFO:src.youtube_fetcher:Collected 753/2000 ids
# INFO:src.youtube_fetcher:Collected 754/2000 ids
# INFO:src.youtube_fetcher:Collected 755/2000 ids
# INFO:src.youtube_fetcher:Collected 756/2000 ids
# INFO:src.youtube_fetcher:Collected 757/2000 ids
# INFO:src.youtube_fetcher:Collected 758/2000 ids
# INFO:src.youtube_fetcher:Collected 759/2000 ids
# INFO:src.youtube_fetcher:Collected 760/2000 ids
# INFO:src.youtube_fetcher:Collected 761/2000 ids
# INFO:src.youtube_fetcher:Collected 762/2000 ids
# INFO:src.youtube_fetcher:Collected 763/2000 ids
# INFO:src.youtube_fetcher:Collected 764/2000 ids
# INFO:src.youtube_fetcher:Collected 765/2000 ids
# INFO:src.youtube_fetcher:Collected 766/2000 ids
# INFO:src.youtube_fetcher:Collected 767/2000 ids
# INFO:src.youtube_fetcher:Collected 768/2000 ids
# INFO:src.youtube_fetcher:Collected 769/2000 ids
# INFO:src.youtube_fetcher:Collected 770/2000 ids
# INFO:src.youtube_fetcher:Collected 771/2000 ids
# INFO:src.youtube_fetcher:Collected 772/2000 ids
# INFO:src.youtube_fetcher:Collected 773/2000 ids
# INFO:src.youtube_fetcher:Collected 774/2000 ids
# INFO:src.youtube_fetcher:Collected 775/2000 ids
# INFO:src.youtube_fetcher:Collected 776/2000 ids
# INFO:src.youtube_fetcher:Collected 777/2000 ids
# INFO:src.youtube_fetcher:Collected 778/2000 ids
# INFO:src.youtube_fetcher:Collected 779/2000 ids
# INFO:src.youtube_fetcher:Collected 780/2000 ids
# INFO:src.youtube_fetcher:Collected 781/2000 ids
# INFO:src.youtube_fetcher:Collected 782/2000 ids
# INFO:src.youtube_fetcher:Collected 783/2000 ids
# INFO:src.youtube_fetcher:Collected 784/2000 ids
# INFO:src.youtube_fetcher:Collected 785/2000 ids
# INFO:src.youtube_fetcher:Collected 786/2000 ids
# INFO:src.youtube_fetcher:Collected 787/2000 ids
# INFO:src.youtube_fetcher:Collected 788/2000 ids
# INFO:src.youtube_fetcher:Collected 789/2000 ids
# INFO:src.youtube_fetcher:Collected 790/2000 ids
# INFO:src.youtube_fetcher:Collected 791/2000 ids
# INFO:src.youtube_fetcher:Collected 792/2000 ids
# INFO:src.youtube_fetcher:Collected 793/2000 ids
# INFO:src.youtube_fetcher:Collected 794/2000 ids
# INFO:src.youtube_fetcher:Collected 795/2000 ids
# INFO:src.youtube_fetcher:Collected 796/2000 ids
# INFO:src.youtube_fetcher:Collected 797/2000 ids
# INFO:src.youtube_fetcher:Collected 798/2000 ids
# INFO:src.youtube_fetcher:Collected 799/2000 ids
# INFO:src.youtube_fetcher:Collected 800/2000 ids
# INFO:src.youtube_fetcher:Collected 801/2000 ids
# INFO:src.youtube_fetcher:Collected 802/2000 ids
# INFO:src.youtube_fetcher:Collected 803/2000 ids
# INFO:src.youtube_fetcher:Collected 804/2000 ids
# INFO:src.youtube_fetcher:Collected 805/2000 ids
# INFO:src.youtube_fetcher:Collected 806/2000 ids
# INFO:src.youtube_fetcher:Collected 807/2000 ids
# INFO:src.youtube_fetcher:Collected 808/2000 ids
# INFO:src.youtube_fetcher:Collected 809/2000 ids
# INFO:src.youtube_fetcher:Collected 810/2000 ids
# INFO:src.youtube_fetcher:Collected 811/2000 ids
# INFO:src.youtube_fetcher:Collected 812/2000 ids
# INFO:src.youtube_fetcher:Collected 813/2000 ids
# INFO:src.youtube_fetcher:Collected 814/2000 ids
# INFO:src.youtube_fetcher:Collected 815/2000 ids
# INFO:src.youtube_fetcher:Collected 816/2000 ids
# INFO:src.youtube_fetcher:Collected 817/2000 ids
# INFO:src.youtube_fetcher:Collected 818/2000 ids
# INFO:src.youtube_fetcher:Collected 819/2000 ids
# INFO:src.youtube_fetcher:Collected 820/2000 ids
# INFO:src.youtube_fetcher:Collected 821/2000 ids
# INFO:src.youtube_fetcher:Collected 822/2000 ids
# INFO:src.youtube_fetcher:Collected 823/2000 ids
# INFO:src.youtube_fetcher:Collected 824/2000 ids
# INFO:src.youtube_fetcher:Collected 825/2000 ids
# INFO:src.youtube_fetcher:Collected 826/2000 ids
# INFO:src.youtube_fetcher:Collected 827/2000 ids
# INFO:src.youtube_fetcher:Collected 828/2000 ids
# INFO:src.youtube_fetcher:Collected 829/2000 ids
# INFO:src.youtube_fetcher:Collected 830/2000 ids
# INFO:src.youtube_fetcher:Collected 831/2000 ids
# INFO:src.youtube_fetcher:Collected 832/2000 ids
# INFO:src.youtube_fetcher:Collected 833/2000 ids
# INFO:src.youtube_fetcher:Collected 834/2000 ids
# INFO:src.youtube_fetcher:Collected 835/2000 ids
# INFO:src.youtube_fetcher:Collected 836/2000 ids
# INFO:src.youtube_fetcher:Collected 837/2000 ids
# INFO:src.youtube_fetcher:Collected 838/2000 ids
# INFO:src.youtube_fetcher:Collected 839/2000 ids
# INFO:src.youtube_fetcher:Collected 840/2000 ids
# INFO:src.youtube_fetcher:Collected 841/2000 ids
# INFO:src.youtube_fetcher:Collected 842/2000 ids
# INFO:src.youtube_fetcher:Collected 843/2000 ids
# INFO:src.youtube_fetcher:Collected 844/2000 ids
# INFO:src.youtube_fetcher:Collected 845/2000 ids
# INFO:src.youtube_fetcher:Collected 846/2000 ids
# INFO:src.youtube_fetcher:Collected 847/2000 ids
# INFO:src.youtube_fetcher:Collected 848/2000 ids
# INFO:src.youtube_fetcher:Collected 849/2000 ids
# INFO:src.youtube_fetcher:Collected 850/2000 ids
# INFO:src.youtube_fetcher:Collected 851/2000 ids
# INFO:src.youtube_fetcher:Collected 852/2000 ids
# INFO:src.youtube_fetcher:Collected 853/2000 ids
# INFO:src.youtube_fetcher:Collected 854/2000 ids
# INFO:src.youtube_fetcher:Collected 855/2000 ids
# INFO:src.youtube_fetcher:Collected 856/2000 ids
# INFO:src.youtube_fetcher:Collected 857/2000 ids
# INFO:src.youtube_fetcher:Collected 858/2000 ids
# INFO:src.youtube_fetcher:Collected 859/2000 ids
# INFO:src.youtube_fetcher:Collected 860/2000 ids
# INFO:src.youtube_fetcher:Collected 861/2000 ids
# INFO:src.youtube_fetcher:Collected 862/2000 ids
# INFO:src.youtube_fetcher:Collected 863/2000 ids
# INFO:src.youtube_fetcher:Collected 864/2000 ids
# INFO:src.youtube_fetcher:Collected 865/2000 ids
# INFO:src.youtube_fetcher:Collected 866/2000 ids
# INFO:src.youtube_fetcher:Collected 867/2000 ids
# INFO:src.youtube_fetcher:Collected 868/2000 ids
# INFO:src.youtube_fetcher:Collected 869/2000 ids
# INFO:src.youtube_fetcher:Collected 870/2000 ids
# INFO:src.youtube_fetcher:Collected 871/2000 ids
# INFO:src.youtube_fetcher:Collected 872/2000 ids
# INFO:src.youtube_fetcher:Collected 873/2000 ids
# INFO:src.youtube_fetcher:Collected 874/2000 ids
# INFO:src.youtube_fetcher:Collected 875/2000 ids
# INFO:src.youtube_fetcher:Collected 876/2000 ids
# INFO:src.youtube_fetcher:Collected 877/2000 ids
# INFO:src.youtube_fetcher:Collected 878/2000 ids
# INFO:src.youtube_fetcher:Collected 879/2000 ids
# INFO:src.youtube_fetcher:Collected 880/2000 ids
# INFO:src.youtube_fetcher:Collected 881/2000 ids
# INFO:src.youtube_fetcher:Collected 882/2000 ids
# INFO:src.youtube_fetcher:Collected 883/2000 ids
# INFO:src.youtube_fetcher:Collected 884/2000 ids
# INFO:src.youtube_fetcher:Collected 885/2000 ids
# INFO:src.youtube_fetcher:Collected 886/2000 ids
# INFO:src.youtube_fetcher:Collected 887/2000 ids
# INFO:src.youtube_fetcher:Collected 888/2000 ids
# INFO:src.youtube_fetcher:Collected 889/2000 ids
# INFO:src.youtube_fetcher:Collected 890/2000 ids
# INFO:src.youtube_fetcher:Collected 891/2000 ids
# INFO:src.youtube_fetcher:Collected 892/2000 ids
# INFO:src.youtube_fetcher:Collected 893/2000 ids
# INFO:src.youtube_fetcher:Collected 894/2000 ids
# INFO:src.youtube_fetcher:Collected 895/2000 ids
# INFO:src.youtube_fetcher:Collected 896/2000 ids
# INFO:src.youtube_fetcher:Collected 897/2000 ids
# INFO:src.youtube_fetcher:Collected 898/2000 ids
# INFO:src.youtube_fetcher:Collected 899/2000 ids
# INFO:src.youtube_fetcher:Collected 900/2000 ids
# INFO:src.youtube_fetcher:Collected 901/2000 ids
# INFO:src.youtube_fetcher:Collected 902/2000 ids
# INFO:src.youtube_fetcher:Collected 903/2000 ids
# INFO:src.youtube_fetcher:Collected 904/2000 ids
# INFO:src.youtube_fetcher:Collected 905/2000 ids
# INFO:src.youtube_fetcher:Collected 906/2000 ids
# INFO:src.youtube_fetcher:Collected 907/2000 ids
# INFO:src.youtube_fetcher:Collected 908/2000 ids
# INFO:src.youtube_fetcher:Collected 909/2000 ids
# INFO:src.youtube_fetcher:Collected 910/2000 ids
# INFO:src.youtube_fetcher:Collected 911/2000 ids
# INFO:src.youtube_fetcher:Collected 912/2000 ids
# INFO:src.youtube_fetcher:Collected 913/2000 ids
# INFO:src.youtube_fetcher:Collected 914/2000 ids
# INFO:src.youtube_fetcher:Collected 915/2000 ids
# INFO:src.youtube_fetcher:Collected 916/2000 ids
# INFO:src.youtube_fetcher:Collected 917/2000 ids
# INFO:src.youtube_fetcher:Collected 918/2000 ids
# INFO:src.youtube_fetcher:Collected 919/2000 ids
# INFO:src.youtube_fetcher:Collected 920/2000 ids
# INFO:src.youtube_fetcher:Collected 921/2000 ids
# INFO:src.youtube_fetcher:Collected 922/2000 ids
# INFO:src.youtube_fetcher:Collected 923/2000 ids
# INFO:src.youtube_fetcher:Collected 924/2000 ids
# INFO:src.youtube_fetcher:Collected 925/2000 ids
# INFO:src.youtube_fetcher:Collected 926/2000 ids
# INFO:src.youtube_fetcher:Collected 927/2000 ids
# INFO:src.youtube_fetcher:Collected 928/2000 ids
# INFO:src.youtube_fetcher:Collected 929/2000 ids
# INFO:src.youtube_fetcher:Collected 930/2000 ids
# INFO:src.youtube_fetcher:Collected 931/2000 ids
# INFO:src.youtube_fetcher:Collected 932/2000 ids
# INFO:src.youtube_fetcher:Collected 933/2000 ids
# INFO:src.youtube_fetcher:Collected 934/2000 ids
# INFO:src.youtube_fetcher:Collected 935/2000 ids
# INFO:src.youtube_fetcher:Collected 936/2000 ids
# INFO:src.youtube_fetcher:Collected 937/2000 ids
# INFO:src.youtube_fetcher:Collected 938/2000 ids
# INFO:src.youtube_fetcher:Collected 939/2000 ids
# INFO:src.youtube_fetcher:Collected 940/2000 ids
# INFO:src.youtube_fetcher:Collected 941/2000 ids
# INFO:src.youtube_fetcher:Collected 942/2000 ids
# INFO:src.youtube_fetcher:Collected 943/2000 ids
# INFO:src.youtube_fetcher:Collected 944/2000 ids
# INFO:src.youtube_fetcher:Collected 945/2000 ids
# INFO:src.youtube_fetcher:Collected 946/2000 ids
# INFO:src.youtube_fetcher:Collected 947/2000 ids
# INFO:src.youtube_fetcher:Collected 948/2000 ids
# INFO:src.youtube_fetcher:Collected 949/2000 ids
# INFO:src.youtube_fetcher:Collected 950/2000 ids
# INFO:src.youtube_fetcher:Collected 951/2000 ids
# INFO:src.youtube_fetcher:Collected 952/2000 ids
# INFO:src.youtube_fetcher:Collected 953/2000 ids
# INFO:src.youtube_fetcher:Collected 954/2000 ids
# INFO:src.youtube_fetcher:Collected 955/2000 ids
# INFO:src.youtube_fetcher:Collected 956/2000 ids
# INFO:src.youtube_fetcher:Collected 957/2000 ids
# INFO:src.youtube_fetcher:Collected 958/2000 ids
# INFO:src.youtube_fetcher:Collected 959/2000 ids
# INFO:src.youtube_fetcher:Collected 960/2000 ids
# INFO:src.youtube_fetcher:Collected 961/2000 ids
# INFO:src.youtube_fetcher:Collected 962/2000 ids
# INFO:src.youtube_fetcher:Collected 963/2000 ids
# INFO:src.youtube_fetcher:Collected 964/2000 ids
# INFO:src.youtube_fetcher:Collected 965/2000 ids
# INFO:src.youtube_fetcher:Collected 966/2000 ids
# INFO:src.youtube_fetcher:Collected 967/2000 ids
# INFO:src.youtube_fetcher:Collected 968/2000 ids
# INFO:src.youtube_fetcher:Collected 969/2000 ids
# INFO:src.youtube_fetcher:Collected 970/2000 ids
# INFO:src.youtube_fetcher:Collected 971/2000 ids
# INFO:src.youtube_fetcher:Collected 972/2000 ids
# INFO:src.youtube_fetcher:Collected 973/2000 ids
# INFO:src.youtube_fetcher:Collected 974/2000 ids
# INFO:src.youtube_fetcher:Collected 975/2000 ids
# INFO:src.youtube_fetcher:Collected 976/2000 ids
# INFO:src.youtube_fetcher:Collected 977/2000 ids
# INFO:src.youtube_fetcher:Collected 978/2000 ids
# INFO:src.youtube_fetcher:Collected 979/2000 ids
# INFO:src.youtube_fetcher:Collected 980/2000 ids
# INFO:src.youtube_fetcher:Collected 981/2000 ids
# INFO:src.youtube_fetcher:Collected 982/2000 ids
# INFO:src.youtube_fetcher:Collected 983/2000 ids
# INFO:src.youtube_fetcher:Collected 984/2000 ids
# INFO:src.youtube_fetcher:Collected 985/2000 ids
# INFO:src.youtube_fetcher:Collected 986/2000 ids
# INFO:src.youtube_fetcher:Collected 987/2000 ids
# INFO:src.youtube_fetcher:Collected 988/2000 ids
# INFO:src.youtube_fetcher:Collected 989/2000 ids
# INFO:src.youtube_fetcher:Collected 990/2000 ids
# INFO:src.youtube_fetcher:Collected 991/2000 ids
# INFO:src.youtube_fetcher:Collected 992/2000 ids
# INFO:src.youtube_fetcher:Collected 993/2000 ids
# INFO:src.youtube_fetcher:Collected 994/2000 ids
# INFO:src.youtube_fetcher:Collected 995/2000 ids
# INFO:src.youtube_fetcher:Collected 996/2000 ids
# INFO:src.youtube_fetcher:Collected 997/2000 ids
# INFO:src.youtube_fetcher:Collected 998/2000 ids
# INFO:src.youtube_fetcher:Collected 999/2000 ids
# INFO:src.youtube_fetcher:Collected 1000/2000 ids
# ...
# INFO:src.youtube_fetcher:Fetched video: How to Play Popular Makossa Notes on Keyboard #makossa #shorts (2023-11-04T22:07:47Z)
# INFO:src.youtube_fetcher:Fetched video: Country Pickin' for Ukulele in 14 seconds #Shorts (2022-10-13T23:05:48Z)
# INFO:src.youtube_fetcher:Fetched video: Magic of Pentatonic scale explained by Amit sharma || Fingerstyle Guitar tutorial in Hindi (2024-08-07T16:02:10Z)
# INFO:src.youtube_fetcher:Fetched video: 🔥 Unlock the Smooth & Melodic Power of G Major Pentatonic on Bass! 🎸🔥 (2025-03-12T20:19:21Z)
# INFO:src.youtube_fetcher:Fetched video: Get Started With Double Stops on Guitar - Intermediate Lead Guitar Lesson (2024-01-05T14:00:33Z)
# INFO:src.youtube_fetcher:Fetched video: Chord Progressions 101 (Piano Lesson) (2024-05-24T14:00:30Z)
# INFO:src.youtube_fetcher:Fetched video: Iris by Goo Goo Dolls STANDARD TUNING Guitar Tutorial - Guitar Lessons with Stuart! (2024-05-19T13:15:03Z)
# INFO:src.youtube_fetcher:Fetched video: The Ultimate GUITAR SOLO Guide (2021-04-16T14:56:03Z)
# INFO:src.youtube_fetcher:Fetched video: Songs Intermediate Players Should be able to Play (2023-05-09T15:48:12Z)
# INFO:src.youtube_fetcher:Fetched video: Ambarsariya song guitar intro|| #music #shorts #guitarlesson #bollywood (2025-05-29T13:30:10Z)
# INFO:src.youtube_fetcher:Fetched video: The BEST Guitar Scale For Soloing! (2024-12-15T22:02:11Z)
# INFO:src.youtube_fetcher:Fetched video: Beautiful bass lick use on 5 chord, learn it🎸 #shorts (2023-09-24T22:11:10Z)
# INFO:src.youtube_fetcher:Fetched video: THE EASIEST GUITAR RIFFS TO START WITH✅ 🎸 (2024-03-18T17:02:36Z)
# INFO:src.youtube_fetcher:Fetched video: Fix This Now for Easier Playing 🙌🏻🎻 #tips #violintips #violinteacher #learning #usastudents (2024-08-07T19:08:36Z)
# INFO:src.youtube_fetcher:Fetched video: Jingle Bell Rock 🎄🔔🎶 (2024-12-15T14:00:28Z)
# INFO:src.youtube_fetcher:Fetched video: 4 Ridiculously Effective Guitar Exercises (2025-01-24T12:29:24Z)
# INFO:src.youtube_fetcher:Fetched video: Learn How To Read TAB in 5 Minutes (2014-02-14T01:33:03Z)
# INFO:src.youtube_fetcher:Fetched video: Read Sheet Music in 7 MINUTES! (guitar) (2021-03-15T18:19:40Z)
# INFO:src.youtube_fetcher:Fetched video: Tim Henson Explaining How To Mastering Sweep Picking (2025-02-09T14:03:20Z)
# INFO:src.youtube_fetcher:Fetched video: Bollywood songs on Guitar (2025-02-22T05:20:00Z)
# INFO:src.youtube_fetcher:Fetched video: Add Left Hand Chords to Improve Your Piano Solos (2023-03-31T17:14:23Z)
# INFO:src.youtube_fetcher:Fetched video: The LEGENDARY picking pattern - 'Travis Picking' (2019-12-30T15:54:24Z)
# INFO:src.youtube_fetcher:Fetched video: Easy chords for beginners (2025-08-12T16:39:34Z)
# INFO:src.youtube_fetcher:Fetched video: EPIC Funky Bass Lesson! (With Tabs) (2024-08-27T15:53:57Z)
# INFO:src.youtube_fetcher:Fetched video: Around The Circle! (2024-09-08T15:00:31Z)
# INFO:src.youtube_fetcher:Fetched video: Easy Strumming pattern for Beginners (2022-05-19T15:22:52Z)
# INFO:src.youtube_fetcher:Fetched video: 5 Great Intermediate Songs to Play on Guitar! 🎸 (2025-01-11T14:45:04Z)
# INFO:src.youtube_fetcher:Recieved 50 items in metadata batch 36
# INFO:src.youtube_fetcher:Fetched video: 5 Minute Beginner Strumming Workout & Technique Lesson! (How to Strum/Tutorial) (2018-11-26T17:49:21Z)
# INFO:src.youtube_fetcher:Fetched video: 5 easy Delta Blues riffs - Guitar lesson with a guitar teacher (2024-08-15T15:00:15Z)
# INFO:src.youtube_fetcher:Fetched video: Feliz Navidad - 4 chord Christmas song guitar lesson (2023-12-05T17:46:29Z)
# INFO:src.youtube_fetcher:Fetched video: Feliz Navidad - 4 chord Christmas song guitar lesson (2023-12-05T17:46:29Z)
# INFO:src.youtube_fetcher:Fetched video: Pro Improvisor VS Self-Taught Improvisor (2022-12-06T15:40:05Z)
# INFO:src.youtube_fetcher:Fetched video: My 6 year guitar progress! (2023-03-14T16:10:11Z)
# INFO:src.youtube_fetcher:Fetched video: Beginners Vs professionals practicing piano #shorts (2023-04-23T23:15:08Z)
# INFO:src.youtube_fetcher:Fetched video: Guitar Scales Explained So They ACTUALLY Make Sense! (2025-04-09T14:00:56Z)
# INFO:src.youtube_fetcher:Fetched video: 5 Easy Acoustic Songs for Beginners! (2024-09-27T16:58:24Z)
# INFO:src.youtube_fetcher:Fetched video: Learn and understand Barre chords / Barr chords / Bar chords Complete guitar lesson with Musicwale (2023-06-10T10:30:10Z)
# INFO:src.youtube_fetcher:Fetched video: 3 ways of playing F chord, Guitar Lesson, Beginner Intermediate, Advanced (2020-07-09T11:20:54Z)
# INFO:src.youtube_fetcher:Fetched video: Impress on piano with 3 NOTES!! (Iconic riff) #pianotutorial #shorts (2023-09-01T14:00:30Z)
# INFO:src.youtube_fetcher:Fetched video: Guitar Tutorial for Beginners in 5 minutes | Basic guitar lessons (2/30) (2022-07-19T11:01:47Z)
# INFO:src.youtube_fetcher:Fetched video: How to Get Good at Ukulele Chords (The 8 Steps I Followed) (2021-10-09T14:46:49Z)
# INFO:src.youtube_fetcher:Fetched video: John Mayer Explains: Phrasing Solos Like a Singer (2023-12-09T17:30:02Z)
# INFO:src.youtube_fetcher:Fetched video: Tim Henson Explaining - Master the Fingerpick Technique (2025-02-12T07:47:33Z)
# INFO:src.youtube_fetcher:Fetched video: Sailor Song Gigi Perez Ukulele Tutorial // Sailor Song Ukulele Lesson (2024-12-22T00:55:59Z)
# INFO:src.youtube_fetcher:Fetched video: Yellow by Coldplay Easy Guitar Tutorial 🤍 #guitar (2024-06-18T06:11:47Z)
# INFO:src.youtube_fetcher:Fetched video: When you don't know classical music part 2 (2025-01-15T13:00:40Z)
# INFO:src.youtube_fetcher:Fetched video: Learn this alt picking lick (Free tab) (2023-11-26T15:07:52Z)
# INFO:src.youtube_fetcher:Fetched video: 4 Hard Truths About Guitar (2023-05-03T17:37:28Z)
# INFO:src.youtube_fetcher:Fetched video: Tommy Emmanuel Teaches 4 Steps To Fingerstyle Guitar Technique | Reverb Learn To Play (2018-03-16T14:51:53Z)
# INFO:src.youtube_fetcher:Fetched video: How to Find The Chords Of Any Song by Yourself! - Guitar Lesson | Shorts (2022-04-09T13:00:34Z)
# INFO:src.youtube_fetcher:Fetched video: 30 Day Beginner Challenge [Day 1] Guitar Lessons For Beginners (2021-01-03T09:00:11Z)
# INFO:src.youtube_fetcher:Fetched video: 🎸 Playing the World’s Hardest Guitar Song BLINFOLDED (2024-09-07T17:10:25Z)
# INFO:src.youtube_fetcher:Fetched video: Rap songs with iconic guitar riffs! (2023-09-27T19:45:35Z)
# INFO:src.youtube_fetcher:Fetched video: Sweep Picking 02 - 3 strings sweeps. #guitar #guitarlesson #guitartutorial #guitarist #musician (2024-10-30T19:30:31Z)
# INFO:src.youtube_fetcher:Fetched video: How To Read Guitar Tabs (Beginner Guide - ALL SYMBOLS) (2021-01-21T18:31:13Z)
# INFO:src.youtube_fetcher:Fetched video: How to play august 10 on ukulele easy!! (2025-02-02T17:43:35Z)
# INFO:src.youtube_fetcher:Fetched video: Master the Chuck: Ukulele & Guitar Techniques Revealed! (2024-10-07T13:21:31Z)
# INFO:src.youtube_fetcher:Fetched video: Here’s a ridiculously simple country guitar lick. #countryguitar #guitarlick #guitarlesson (2025-07-06T16:53:17Z)
# INFO:src.youtube_fetcher:Fetched video: 3 tricks every rock guitarist should know (2022-12-07T00:27:44Z)
# INFO:src.youtube_fetcher:Fetched video: 12 Bar Blues Lesson For Beginners (2021-01-25T15:00:11Z)
# INFO:src.youtube_fetcher:Fetched video: How to Play “Creep” - Radiohead 🎸 #reels #guitartutorial r (2024-03-22T16:56:37Z)
# INFO:src.youtube_fetcher:Fetched video: Easy Strumming Pattern! (2022-11-20T13:45:01Z)
# INFO:src.youtube_fetcher:Fetched video: Happy Birthday Intermediate chord melody embellishments  🎸 (2024-11-10T15:00:30Z)
# INFO:src.youtube_fetcher:Fetched video: 3 BAD Picking Technique Habits ⛔ (2022-06-09T14:30:00Z)
# INFO:src.youtube_fetcher:Fetched video: Reharmonization doesn’t have to be complicated. Here is a basic way to reharmonize a chord. (2023-06-21T20:13:37Z)
# INFO:src.youtube_fetcher:Fetched video: Buying Your First Acoustic Guitar (5 Things You MUST Consider) | A Beginner's Guide (2021-04-07T02:59:39Z)
# INFO:src.youtube_fetcher:Fetched video: The Heart Melter Chords (2023-10-13T15:00:32Z)
# INFO:src.youtube_fetcher:Fetched video: INSTANTLY Make Your Blues Guitar Rhythm Sound Cooler (2025-05-01T20:00:33Z)
# INFO:src.youtube_fetcher:Fetched video: 8 AMAZING yet SIMPLE Guitar Chords for Beginners | Guitar Lesson - How To | @Siffguitar (2021-09-27T07:00:15Z)
# INFO:src.youtube_fetcher:Fetched video: Add FILLS to your songs (2024-09-30T14:30:32Z)
# INFO:src.youtube_fetcher:Fetched video: NO CAPO?? how to make your own! #capo #guitar #guitarplayer #easy #hack (2024-12-20T03:27:40Z)
# INFO:src.youtube_fetcher:Fetched video: How to play the Bm Chord 2 ways on Guitar | Easiest Beginner Free Online Guitar Lessons (2025-04-15T12:00:43Z)
# INFO:src.youtube_fetcher:Fetched video: Complete Intermediate Guitar Course || intermediate Guitar Lesson (2024-12-09T05:30:00Z)
# INFO:src.youtube_fetcher:Fetched video: Coldplay "Yellow" SUPER EASY Acoustic Guitar Lesson + Tutorial | Chords & Strumming w/ Visuals (2024-01-21T11:00:17Z)
# INFO:src.youtube_fetcher:Fetched video: 3 Easiest Songs Anyone Can Play on Guitar! (2024-09-04T15:07:27Z)
# INFO:src.youtube_fetcher:Fetched video: 12 MUST-HAVE Chords for Modern Worship Guitar [Electric and Acoustic] (2024-02-23T14:44:20Z)
# INFO:src.youtube_fetcher:Fetched video: How to Impress A… 🎸 (2025-03-27T15:59:32Z)
# INFO:src.youtube_fetcher:Recieved 50 items in metadata batch 37
# INFO:src.youtube_fetcher:Fetched video: How’d I do?! #guitar #acoustic #fingerstyle #music #acousticfingerstyle (2024-02-17T23:13:23Z)
# INFO:src.youtube_fetcher:Fetched video: Humbled During Acoustic Guitar Practice #shorts (2023-11-16T19:42:25Z)
# INFO:src.youtube_fetcher:Fetched video: Songs intermediate guitarists should be able to play (2023-06-05T16:49:03Z)
# INFO:src.youtube_fetcher:Fetched video: Blues Chord Lesson | Play better blues chords in 3 easy steps (Beginner, Intermediate, Advanced) (2024-11-21T21:00:20Z)
# INFO:src.youtube_fetcher:Fetched video: INSANE😱 Flamenco🔥in Señorita🎵Guitar🎸Zindagi na Milegi Sobara#guitar #guitarist #bollywoodsongs #fun (2025-07-11T12:27:14Z)
# INFO:src.youtube_fetcher:Fetched video: Barbaad from saiyaara | Guitar lessons | Easy for beginners | 4 chords (2025-08-02T15:40:42Z)
# INFO:src.youtube_fetcher:Fetched video: 5 Things EVERY Bass Player SHOULD Master (2020-04-26T21:34:36Z)
# INFO:src.youtube_fetcher:Fetched video: Should you start on Acoustic, Electric or Classical guitar? (2025-04-03T14:00:24Z)
# INFO:src.youtube_fetcher:Fetched video: MUSIC THEORY Every Guitar Player should KNOW (2025-06-03T14:15:03Z)
# INFO:src.youtube_fetcher:Fetched video: Arijit Singh🔥KILLING on GUITAR🎸#guitar #acoustic #bollywoodsongs #arijitsingh #explore #music #fun (2025-07-30T12:23:37Z)
# INFO:src.youtube_fetcher:Fetched video: much easier than it looks #piano #beethoven #sonata #moonlight #music #easy #hard #shorts #learn (2024-10-27T21:27:33Z)
# INFO:src.youtube_fetcher:Fetched video: 20 Blues Rock Guitar Licks for Beginner-Intermediate Players (2021-10-03T16:34:45Z)
# INFO:src.youtube_fetcher:Fetched video: Pal pal by Afusic | Guitar lessons | only 4 chords Easy strumming (2025-06-12T12:52:03Z)
# INFO:src.youtube_fetcher:Fetched video: Beginner vs. Pro: Blackened 🎸 How would YOU play it? #metal (2025-01-20T13:21:17Z)
# INFO:src.youtube_fetcher:Fetched video: Can Guitarist Read Sheet Music? #guitar (2024-02-22T01:15:53Z)
# INFO:src.youtube_fetcher:Fetched video: BIGGEST MISTAKE made by BEGINNER Guitarists (2025-07-30T08:46:24Z)
# INFO:src.youtube_fetcher:Fetched video: 1 Year Guitarist Vs 1 Month Bassist (2024-10-10T01:00:57Z)
# INFO:src.youtube_fetcher:Fetched video: Best Fingerpicking Songs on Guitar (2024-08-31T15:08:32Z)
# INFO:src.youtube_fetcher:Fetched video: SHRED BLUES LICKS! #guitarshred #shredguitar #guitarsolo #guitars #gibsonguitar #bluesguitar (2023-10-04T16:39:17Z)
# INFO:src.youtube_fetcher:Fetched video: Strumming Without a Pick: Mastering Acoustic Guitar Technique! #guitarlesson #guitartutorial (2024-06-10T09:45:02Z)
# INFO:src.youtube_fetcher:Fetched video: The most amazing bass technique ever (2024-05-19T18:00:26Z)
# INFO:src.youtube_fetcher:Fetched video: 5 Picking Tips To Save YEARS Of Guitar Practice! (2021-05-27T13:43:10Z)
# INFO:src.youtube_fetcher:Fetched video: Smells Like Teen Spirit - Nirvana Guitar Lesson + Tutorial (2023-01-18T15:00:39Z)
# INFO:src.youtube_fetcher:Fetched video: Blues Guitar Lesson - The Piedmont Roll - Rev. Robert Jones (2019-05-31T16:13:31Z)
# INFO:src.youtube_fetcher:Fetched video: INSTANTLY improve your sight reading 👀 #piano #pianolesson #musicians #pianist #sightreading #shorts (2024-05-15T19:46:13Z)
# INFO:src.youtube_fetcher:Fetched video: Bass player beginner tips (you need to know!) [April Kae on Bass] #aprilkae #basslessonswithapril (2024-12-28T16:00:13Z)
# INFO:src.youtube_fetcher:Fetched video: Finger stretching exercises every GUITARIST should do (2025-06-26T15:25:07Z)
# INFO:src.youtube_fetcher:Fetched video: How to Play “Iris” - Goo Goo Dolls (2024-09-05T14:12:14Z)
# INFO:src.youtube_fetcher:Fetched video: Saiyaara - Electric Guitar | Quick Lesson (2025-08-01T14:30:48Z)
# INFO:src.youtube_fetcher:Fetched video: 10 Levels of Metal 🔥 #shorts #metal #guitarist (2024-05-13T15:50:24Z)
# INFO:src.youtube_fetcher:Fetched video: Level up your Basic Chords by Usjng Extension & voicings beginner Fingerstyle lesson by Amit Sharma (2025-08-17T04:29:11Z)
# INFO:src.youtube_fetcher:Fetched video: This is the way you should learn scales to write iconic metal riffs! 🤘 (2024-09-16T16:41:20Z)
# INFO:src.youtube_fetcher:Fetched video: Coolest Fingerpicking. Ever Hindi Fingerstyle tutorial by Amit sharma || Fingerstyle for beginner (2024-07-28T17:15:51Z)
# INFO:src.youtube_fetcher:Fetched video: Cheapest guitars | 2000/- Guitar | Easy Guitar tips for beginners by Musicwale (2023-02-13T12:30:11Z)
# INFO:src.youtube_fetcher:Fetched video: The 1st SHRED Lick you should learn (2022-02-05T04:52:15Z)
# INFO:src.youtube_fetcher:Fetched video: 5 EASIEST Violin Pieces you should learn (2025-07-22T16:30:37Z)
# INFO:src.youtube_fetcher:Fetched video: 505 - The EASIEST Arctic Monkeys Song to Play on Guitar? (2021-06-09T15:00:06Z)
# INFO:src.youtube_fetcher:Fetched video: Samay raina Playing guitar 🎸🎸 (2021-05-14T17:23:07Z)
# INFO:src.youtube_fetcher:Fetched video: Here I Am To Worship || 3-Chord Play-Along with Chords, Lyrics, and Strumming! (2022-12-19T16:00:01Z)
# INFO:src.youtube_fetcher:Fetched video: Blues #blues #guitar #gibson #lespaul #tomofujita (2025-12-23T23:00:12Z)
# INFO:src.youtube_fetcher:Fetched video: How to play Faded by Alan Walker on guitar #guitar #easyguitar #lesson #tutorial (2024-02-23T22:45:00Z)
# INFO:src.youtube_fetcher:Fetched video: 4 Lead Guitar 4 Techniques to MASTER (2017-12-01T19:00:04Z)
# INFO:src.youtube_fetcher:Fetched video: Learn all major scale in guitar | 2025 Easy lessons for beginners (2025-08-11T13:48:41Z)
# INFO:src.youtube_fetcher:Fetched video: 3 Easy Blues Licks (2021-08-12T19:57:38Z)
# INFO:src.youtube_fetcher:Fetched video: Top 5 Acoustic Songs to Play for your Friends | 2021 (2021-03-24T00:57:08Z)
# INFO:src.youtube_fetcher:Fetched video: 10 ACOUSTIC SONGS that taught me guitar (easy to hard) (2020-04-28T13:32:09Z)
# INFO:src.youtube_fetcher:Fetched video: 6 Guitar Exercises You're Probably Doing WRONG (2022-01-27T14:48:10Z)
# INFO:src.youtube_fetcher:Fetched video: Quickest easiest beginner guitar blues lesson (2025-02-04T16:30:00Z)
# INFO:src.youtube_fetcher:Fetched video: Beautiful Chords! Fender Bronco #guitar #chords #fender #jazz #chord #chordmelody #tomofujita (2025-06-02T12:01:41Z)
# INFO:src.youtube_fetcher:Fetched video: The Secret to Beautiful Chord Progressions (2025-05-14T17:23:32Z)
# INFO:src.youtube_fetcher:Recieved 3 items in metadata batch 38
# INFO:src.youtube_fetcher:Fetched video: Learn To SHRED With Just 6 Patterns! (Guitar Lesson + Tabs) (2021-01-23T13:58:04Z)
# INFO:src.youtube_fetcher:Fetched video: PURE ACOUSTIC vs. SEMI-ACOUSTIC Guitar – Which One is Right for You? 🎸🔍 (2025-03-19T11:10:00Z)
# INFO:src.youtube_fetcher:Fetched video: Perfect Guitar Tutorial (Ed Sheeran) Easy Chords Guitar Lesson (2017-08-12T15:00:02Z)
# INFO:src.youtube_fetcher:Finished collecting metadata for 1853 videos
# 1853

# %% [markdown]
# ### Save & Preview

# %%
import pandas as pd

df = pd.DataFrame(meta)
df.head()
# Remove rows with the values of unknown, they'll be saved for the test dataset
test_df = df.query('level == "unknown"').copy()
test_df.to_csv("../data/raw/guitar_sample_test_2.csv")
df = df.drop(df.query("level == 'unknown'").index)
df.to_parquet("../data/raw/guitar_sample_parquet", index=False)

# %%
df.head()
# Out:
#       video_id                                              title  \
# 0  4WVkDrb6d5A           A Good, Quick Intermediate Guitar Lesson
# 1  sDjeY1jI2Z8         5 GREAT chord tricks everyone should know!
# 2  WN4IoK7ecAU  How to Teach Yourself Guitar in 2026 (Save YEA...
# 3  -iV-7XhUMT0  Are You An Intermediate Or Advanced Guitar Pla...
# 4  wH63GHXTHgU  Advanced Chords Practice Routine - Guitar Less...
#
#                                          description  \
# 0  Trying to combine a few concepts into one flui...
# 1  ▶MY NEW COURSE◀ http://nextlevelplaying.com\nK...
# 2  Are you part of the 90% of aspiring guitarists...
# 3  More Guitar Resources:\n🎵 Get my FREE Guitar G...
# 4  Gain access to TABS, exclusive tutorials and o...
#
#                                                 tags           publishedAt  \
# 0  [guitar, sean daniel, guitar lesson, sean dani...  2021-08-15T13:00:02Z
# 1  [paul davids, acoustic, great, tricks, chord t...  2020-03-14T16:59:33Z
# 2  [O.R.-Guitar, how to play, guitar lesson, guit...  2024-02-05T04:46:37Z
# 3  [Marty Schwartz, music, guitar, marty music, g...  2020-09-25T14:00:00Z
# 4  [jazz guitar chords, advanced guitar chords le...  2020-05-05T14:46:45Z
#
#    channelTitle  viewCount  likeCount  duration  \
# 0   Sean Daniel     163929     3868.0  PT12M41S
# 1   Paul Davids    2611079   106425.0  PT14M21S
# 2  Oryam Bisset    3968428   202324.0  PT10M40S
# 3   Marty Music     165635     4986.0   PT10M7S
# 4  swiftlessons     434634    14417.0   PT16M8S
#
#                                          raw_snippet  \
# 0  {'publishedAt': '2021-08-15T13:00:02Z', 'chann...
# 1  {'publishedAt': '2020-03-14T16:59:33Z', 'chann...
# 2  {'publishedAt': '2024-02-05T04:46:37Z', 'chann...
# 3  {'publishedAt': '2020-09-25T14:00:00Z', 'chann...
# 4  {'publishedAt': '2020-05-05T14:46:45Z', 'chann...
#
#                                       raw_statistics         level  \
# 0  {'viewCount': '163929', 'likeCount': '3868', '...  intermediate
# 1  {'viewCount': '2611079', 'likeCount': '106425'...       unknown
# 2  {'viewCount': '3968428', 'likeCount': '202324'...      beginner
# 3  {'viewCount': '165635', 'likeCount': '4986', '...  intermediate
# 4  {'viewCount': '434634', 'likeCount': '14417', ...      beginner
#
#             topic
# 0  Learning songs
# 1          Chords
# 2          Chords
# 3          Chords
# 4          Chords
